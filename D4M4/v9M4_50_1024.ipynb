# %% [markdown]
# # Setup

# %%
# !pip install ultralytics --quiet
# !pip install roboflow --quiet
# !pip install torch torchvision onnx onnx2keras tensorflow --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 780.6/780.6 kB 7.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 45.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 2.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 14.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 21.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 11.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.5 MB/s eta 0:00:00
# WARNING: The candidate selected for download or install is a yanked version: 'opencv-python-headless' candidate (version 4.8.0.74 at https://files.pythonhosted.org/packages/76/02/f128517f3ade4bb5f71e2afd8461dba70e3f466ce745fa1fd1fade9ad1b7/opencv_python_headless-4.8.0.74-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from https://pypi.org/simple/opencv-python-headless/) (requires-python:>=3.6))
# Reason for being yanked: deprecated, use 4.8.0.76
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 43.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for onnx2keras (setup.py) ... done

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.32 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 30.5/78.2 GB disk)

# %%
from ultralytics import YOLO
from IPython.display import display, Image
import shutil
from google.colab import files
import torch
import os
import onnx
from onnx2keras import onnx_to_keras
from roboflow import Roboflow

# %%
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %% [markdown]
# # Data

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets
# Out:
# /content/datasets

# %%
rf = Roboflow(api_key="omDBjHRrb9UFDvmRW9cb")
project = rf.workspace("dataset-jerawat").project("capstone-bjc8v")
version = project.version(9)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.2.32, to fix: `pip install ultralytics==8.0.196`
# Downloading Dataset Version Zip in Capstone-9 to yolov8:: 100%|██████████| 283830/283830 [00:07<00:00, 38232.66it/s]
# Extracting Dataset Version Zip to Capstone-9 in yolov8:: 100%|██████████| 3178/3178 [00:01<00:00, 2703.45it/s]

# %% [markdown]
# # training

# %%
# %cd {HOME}
# !yolo task=detect mode=train model=yolov8s.pt data={dataset.location}/data.yaml epochs=50 imgsz=1024 plots=True
# Out:
# /content
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8s.pt to 'yolov8s.pt'...
# 100% 21.5M/21.5M [00:00<00:00, 229MB/s]
# Ultralytics YOLOv8.2.32 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# engine/trainer: task=detect, mode=train, model=yolov8s.pt, data=/content/datasets/Capstone-9/data.yaml, epochs=50, time=None, patience=100, batch=16, imgsz=1024, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100% 755k/755k [00:00<00:00, 22.2MB/s]
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2117209  ultralytics.nn.modules.head.Detect           [3, [128, 256, 512]]
# Model summary: 225 layers, 11136761 parameters, 11136745 gradients, 28.7 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8n.pt to 'yolov8n.pt'...
# 100% 6.23M/6.23M [00:00<00:00, 133MB/s]
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
# AMP: checks passed ✅
# train: Scanning /content/datasets/Capstone-9/train/labels... 1461 images, 4 backgrounds, 0 corrupt: 100% 1461/1461 [00:00<00:00, 1778.46it/s]
# train: New cache created: /content/datasets/Capstone-9/train/labels.cache
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 464, len(boxes) = 11206. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# val: Scanning /content/datasets/Capstone-9/valid/labels... 61 images, 0 backgrounds, 0 corrupt: 100% 61/61 [00:00<00:00, 711.02it/s]
# val: New cache created: /content/datasets/Capstone-9/valid/labels.cache
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 30, len(boxes) = 420. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# Plotting labels to runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001429, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 1024 train, 1024 val
# Using 2 dataloader workers
# Logging results to runs/detect/train
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      9.72G      2.721      3.665      2.054         26       1024: 100% 92/92 [02:04<00:00,  1.35s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:04<00:00,  2.48s/it]
#                    all         61        420      0.192      0.289      0.171     0.0538
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      10.1G      2.508      2.602      1.937         31       1024: 100% 92/92 [01:48<00:00,  1.18s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:02<00:00,  1.04s/it]
#                    all         61        420      0.232      0.392      0.277     0.0795
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      9.63G      2.487      2.522      1.946         59       1024: 100% 92/92 [01:53<00:00,  1.24s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:02<00:00,  1.19s/it]
#                    all         61        420       0.44      0.335      0.292     0.0869
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      9.49G      2.473      2.541      1.932         41       1024: 100% 92/92 [01:49<00:00,  1.19s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:02<00:00,  1.22s/it]
#                    all         61        420      0.581      0.314      0.288     0.0928
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      9.56G      2.443      2.446      1.872         77       1024: 100% 92/92 [01:49<00:00,  1.19s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:02<00:00,  1.39s/it]
#                    all         61        420      0.398      0.361      0.336     0.0963
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      9.68G      2.431      2.404      1.879         58       1024: 100% 92/92 [01:48<00:00,  1.18s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.11it/s]
#                    all         61        420      0.242      0.344      0.227     0.0723
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      9.85G      2.383      2.348      1.831         95       1024: 100% 92/92 [01:55<00:00,  1.25s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.09it/s]
#                    all         61        420      0.272      0.388      0.289     0.0856
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      9.57G      2.362      2.264      1.811         48       1024: 100% 92/92 [01:52<00:00,  1.22s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.16it/s]
#                    all         61        420      0.385      0.374      0.357      0.117
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      9.59G      2.347      2.266      1.785         55       1024: 100% 92/92 [01:49<00:00,  1.19s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:02<00:00,  1.24s/it]
#                    all         61        420      0.443      0.452      0.396      0.122
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      9.52G      2.339      2.233      1.802        176       1024: 100% 92/92 [01:48<00:00,  1.18s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:02<00:00,  1.13s/it]
#                    all         61        420      0.509      0.439      0.375      0.113
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50       9.8G      2.316      2.191      1.788         43       1024: 100% 92/92 [01:52<00:00,  1.22s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:02<00:00,  1.03s/it]
#                    all         61        420      0.445      0.376      0.367      0.124
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50      9.53G      2.274      2.158      1.776         59       1024: 100% 92/92 [01:50<00:00,  1.20s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:02<00:00,  1.16s/it]
#                    all         61        420      0.446      0.427      0.374       0.12
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50      9.55G      2.261       2.08      1.726         49       1024: 100% 92/92 [01:50<00:00,  1.20s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.13it/s]
#                    all         61        420      0.399      0.457      0.404       0.13
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50       9.8G      2.246       2.09      1.743         44       1024: 100% 92/92 [01:54<00:00,  1.24s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.18it/s]
#                    all         61        420      0.473      0.441      0.422      0.136
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50      10.2G      2.243      2.058      1.723         67       1024: 100% 92/92 [01:50<00:00,  1.21s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:02<00:00,  1.34s/it]
#                    all         61        420      0.416      0.437       0.41      0.137
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50      9.61G      2.209      2.038      1.707         49       1024: 100% 92/92 [01:46<00:00,  1.15s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:02<00:00,  1.06s/it]
#                    all         61        420       0.43      0.407      0.384      0.123
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50      9.46G      2.206      2.008      1.688         20       1024: 100% 92/92 [01:48<00:00,  1.18s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.21it/s]
#                    all         61        420      0.373      0.436      0.393      0.125
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50        10G      2.202       1.96      1.677         52       1024: 100% 92/92 [01:52<00:00,  1.22s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:02<00:00,  1.21s/it]
#                    all         61        420      0.429      0.482      0.441      0.156
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50      10.1G      2.174      1.949      1.669         66       1024: 100% 92/92 [01:46<00:00,  1.15s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:02<00:00,  1.20s/it]
#                    all         61        420      0.508      0.477       0.47      0.161
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50      9.39G      2.153      1.908      1.653         22       1024: 100% 92/92 [01:52<00:00,  1.23s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.18it/s]
#                    all         61        420      0.381      0.483      0.455      0.156
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50        10G      2.154      1.893      1.658         17       1024: 100% 92/92 [01:55<00:00,  1.25s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.26it/s]
#                    all         61        420      0.442       0.52      0.446      0.149
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/50      9.58G      2.147      1.876      1.664         37       1024: 100% 92/92 [01:49<00:00,  1.19s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:02<00:00,  1.17s/it]
#                    all         61        420      0.447      0.505      0.452      0.161
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/50      9.53G      2.117      1.849      1.645         39       1024: 100% 92/92 [01:47<00:00,  1.17s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:02<00:00,  1.05s/it]
#                    all         61        420       0.39      0.511      0.441      0.148
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/50      9.56G      2.126      1.831      1.635         35       1024: 100% 92/92 [01:50<00:00,  1.20s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.15it/s]
#                    all         61        420      0.477      0.472      0.449      0.148
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/50       9.4G      2.084      1.789      1.612         92       1024: 100% 92/92 [01:49<00:00,  1.19s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:02<00:00,  1.30s/it]
#                    all         61        420      0.474      0.518      0.475      0.156
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/50       9.7G      2.071      1.768      1.619         38       1024: 100% 92/92 [01:44<00:00,  1.14s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.18it/s]
#                    all         61        420      0.419      0.478      0.436      0.147
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/50      9.81G      2.057      1.728      1.585         18       1024: 100% 92/92 [01:50<00:00,  1.20s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.21it/s]
#                    all         61        420      0.473      0.449      0.438      0.144
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/50      10.7G      2.043      1.684      1.564         54       1024: 100% 92/92 [01:53<00:00,  1.23s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.25it/s]
#                    all         61        420      0.462      0.432      0.458      0.159
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/50       9.6G      2.019      1.684      1.586         36       1024: 100% 92/92 [01:53<00:00,  1.23s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:02<00:00,  1.11s/it]
#                    all         61        420      0.473      0.515      0.449      0.153
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/50      9.56G      1.994      1.648      1.561         34       1024: 100% 92/92 [01:47<00:00,  1.17s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.06it/s]
#                    all         61        420      0.465      0.511       0.46       0.16
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/50        10G      1.968      1.586      1.527        115       1024: 100% 92/92 [01:50<00:00,  1.20s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.16it/s]
#                    all         61        420      0.468      0.489      0.458      0.159
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50      9.53G      1.976      1.586      1.537         56       1024: 100% 92/92 [01:49<00:00,  1.19s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.16it/s]
#                    all         61        420      0.504      0.517      0.472      0.155
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/50      9.57G      1.969      1.575      1.522         58       1024: 100% 92/92 [01:45<00:00,  1.14s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:02<00:00,  1.19s/it]
#                    all         61        420      0.535      0.481      0.473      0.158
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50      9.55G      1.969      1.555      1.523         41       1024: 100% 92/92 [01:48<00:00,  1.18s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:02<00:00,  1.09s/it]
#                    all         61        420       0.49      0.507      0.479      0.165
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50      9.52G       1.93      1.495      1.493         46       1024: 100% 92/92 [01:50<00:00,  1.20s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.18it/s]
#                    all         61        420      0.455      0.501      0.456      0.161
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50      9.46G      1.904      1.466      1.474         48       1024: 100% 92/92 [01:48<00:00,  1.18s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.17it/s]
#                    all         61        420      0.445      0.502      0.451      0.163
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50      10.3G      1.896      1.458      1.482         27       1024: 100% 92/92 [01:56<00:00,  1.26s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.26it/s]
#                    all         61        420      0.495      0.492       0.47      0.166
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50      9.61G      1.878      1.441      1.471         49       1024: 100% 92/92 [02:02<00:00,  1.33s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:02<00:00,  1.20s/it]
#                    all         61        420      0.491      0.534      0.484      0.166
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50        10G      1.865       1.41       1.46         62       1024: 100% 92/92 [02:01<00:00,  1.32s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:02<00:00,  1.00s/it]
#                    all         61        420      0.472      0.482      0.451      0.164
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50      9.76G      1.862      1.388       1.45         82       1024: 100% 92/92 [01:51<00:00,  1.21s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:02<00:00,  1.07s/it]
#                    all         61        420      0.528      0.501      0.446       0.16
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50      9.79G      1.868      1.374      1.489         27       1024: 100% 92/92 [01:50<00:00,  1.21s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:02<00:00,  1.16s/it]
#                    all         61        420        0.5      0.497      0.468      0.168
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50       9.8G      1.814      1.324      1.459         45       1024: 100% 92/92 [01:46<00:00,  1.16s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:02<00:00,  1.15s/it]
#                    all         61        420       0.47      0.523      0.452      0.165
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50      9.74G      1.796      1.272      1.447         70       1024: 100% 92/92 [01:43<00:00,  1.12s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:02<00:00,  1.13s/it]
#                    all         61        420      0.477      0.521      0.468      0.169
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      9.75G      1.771       1.25      1.444         30       1024: 100% 92/92 [01:45<00:00,  1.15s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.22it/s]
#                    all         61        420       0.49      0.477       0.45      0.162
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      9.75G      1.759      1.212      1.423         42       1024: 100% 92/92 [01:44<00:00,  1.14s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.20it/s]
#                    all         61        420      0.478      0.521      0.456      0.165
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      9.77G      1.735      1.199      1.411         35       1024: 100% 92/92 [01:43<00:00,  1.12s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:02<00:00,  1.15s/it]
#                    all         61        420       0.51      0.491      0.448      0.166
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      9.56G      1.715      1.176      1.405         37       1024: 100% 92/92 [01:45<00:00,  1.15s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.33it/s]
#                    all         61        420      0.502      0.483      0.462      0.167
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      9.77G       1.68      1.155       1.38         27       1024: 100% 92/92 [01:48<00:00,  1.18s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:02<00:00,  1.11s/it]
#                    all         61        420      0.491      0.493      0.464      0.166
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      9.75G      1.685      1.143      1.375         33       1024: 100% 92/92 [01:42<00:00,  1.12s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:02<00:00,  1.07s/it]
#                    all         61        420      0.464      0.512      0.465      0.174
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      9.69G      1.655      1.129      1.371         41       1024: 100% 92/92 [01:47<00:00,  1.17s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.35it/s]
#                    all         61        420      0.468      0.511      0.461      0.168
#
# 50 epochs completed in 1.613 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 22.6MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 22.6MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics YOLOv8.2.32 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11126745 parameters, 0 gradients, 28.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.10it/s]
#                    all         61        420      0.464      0.512      0.465      0.174
#                   Acne         18        253      0.519      0.462      0.416      0.127
#           Dark Circles         36         62      0.682      0.855      0.848      0.354
#               Wrinkles         20        105       0.19      0.219      0.132     0.0399
# Speed: 0.6ms preprocess, 12.4ms inference, 0.0ms loss, 5.3ms postprocess per image
# Results saved to runs/detect/train
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %%
# !ls {HOME}/runs/detect/train/
# Out:
# args.yaml					    PR_curve.png	 train_batch3681.jpg
# confusion_matrix_normalized.png			    R_curve.png		 train_batch3682.jpg
# confusion_matrix.png				    results.csv		 val_batch0_labels.jpg
# events.out.tfevents.1718440865.2ad87a452cc8.4424.0  results.png		 val_batch0_pred.jpg
# F1_curve.png					    train_batch0.jpg	 val_batch1_labels.jpg
# labels_correlogram.jpg				    train_batch1.jpg	 val_batch1_pred.jpg
# labels.jpg					    train_batch2.jpg	 weights
# P_curve.png					    train_batch3680.jpg

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/confusion_matrix.png', width=600)
# Out:
# /content

# %%
# data validasi
# %cd {HOME}
# !yolo task=detect mode=val model={HOME}/runs/detect/train/weights/best.pt data={dataset.location}/data.yaml
# Out:
# /content
# Ultralytics YOLOv8.2.32 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11126745 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /content/datasets/Capstone-9/valid/labels.cache... 61 images, 0 backgrounds, 0 corrupt: 100% 61/61 [00:00<?, ?it/s]
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 30, len(boxes) = 420. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:09<00:00,  2.28s/it]
#                    all         61        420       0.46      0.508      0.465      0.173
#                   Acne         18        253      0.516      0.459      0.417      0.126
#           Dark Circles         36         62      0.681      0.855      0.849      0.353
#               Wrinkles         20        105      0.182       0.21      0.128     0.0398
# Speed: 14.7ms preprocess, 43.6ms inference, 0.0ms loss, 24.6ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model={HOME}/runs/detect/train/weights/best.pt conf=0.25 source={dataset.location}/test/images save=True
# Out:
# /content
# Ultralytics YOLOv8.2.32 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11126745 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/61 /content/datasets/Capstone-9/test/images/04833_png_jpg.rf.29ee5c80c5aec07ec6b828833b94d5e6.jpg: 1024x1024 6 Wrinkless, 32.5ms
# image 2/61 /content/datasets/Capstone-9/test/images/05844_png_jpg.rf.19793b4118a36ad83fb754364ee46f1e.jpg: 1024x1024 4 Wrinkless, 32.5ms
# image 3/61 /content/datasets/Capstone-9/test/images/06764_png_jpg.rf.cdf079a084fceccc93e279998e06fc9e.jpg: 1024x1024 4 Wrinkless, 32.4ms
# image 4/61 /content/datasets/Capstone-9/test/images/105_jpg.rf.fdbb4425709236717e814e854d280150.jpg: 1024x1024 1 Dark Circles, 32.5ms
# image 5/61 /content/datasets/Capstone-9/test/images/106_jpg.rf.3159aec33b574297403c2aceeb01ebeb.jpg: 1024x1024 2 Acnes, 2 Dark Circless, 32.5ms
# image 6/61 /content/datasets/Capstone-9/test/images/107_jpg.rf.e0391272b1a3c328832ae8436d011eb7.jpg: 1024x1024 4 Acnes, 1 Dark Circles, 32.5ms
# image 7/61 /content/datasets/Capstone-9/test/images/111_jpg.rf.6382a61a6bf536c50cb95a3de3fad2b4.jpg: 1024x1024 11 Acnes, 32.5ms
# image 8/61 /content/datasets/Capstone-9/test/images/122_jpg.rf.1302e7fc64f27bc345edff8d490baf9a.jpg: 1024x1024 1 Dark Circles, 1 Wrinkles, 32.5ms
# image 9/61 /content/datasets/Capstone-9/test/images/12_jpg.rf.81bce329d3f673df1e4003cc10b2cc96.jpg: 1024x1024 6 Acnes, 32.6ms
# image 10/61 /content/datasets/Capstone-9/test/images/140_jpg.rf.b3f8129c58af8091662bbe6517fced1e.jpg: 1024x1024 2 Dark Circless, 1 Wrinkles, 32.5ms
# image 11/61 /content/datasets/Capstone-9/test/images/1430618662_1_jpg.rf.ea0032948827f354a6b8c4069a0f6c7f.jpg: 1024x1024 2 Wrinkless, 32.5ms
# image 12/61 /content/datasets/Capstone-9/test/images/192_jpg.rf.f1af9389edd04e6388cf836c81e475ec.jpg: 1024x1024 5 Acnes, 4 Dark Circless, 32.3ms
# image 13/61 /content/datasets/Capstone-9/test/images/198_jpg.rf.7be8e66d86ccb3ffebbc2a7a612f81e5.jpg: 1024x1024 7 Acnes, 28.6ms
# image 14/61 /content/datasets/Capstone-9/test/images/21301_png_jpg.rf.130332966dfde0f52bbb49a80d7f740d.jpg: 1024x1024 7 Wrinkless, 28.6ms
# image 15/61 /content/datasets/Capstone-9/test/images/22986_png_jpg.rf.89353cbf0978442c4d8e5875b0ea85dc.jpg: 1024x1024 2 Wrinkless, 28.5ms
# image 16/61 /content/datasets/Capstone-9/test/images/2352254513_1_jpg.rf.3efc3e9ef6323c05ad79761df023c72f.jpg: 1024x1024 2 Dark Circless, 28.5ms
# image 17/61 /content/datasets/Capstone-9/test/images/240_F_175181761_NaukWVZ1iZTbDytJzuiQqN5Y2Xc0zZ2C_jpg.rf.c8dc28405a3a5e03b93b35b8228bd72b.jpg: 1024x1024 3 Dark Circless, 26.4ms
# image 18/61 /content/datasets/Capstone-9/test/images/240_F_203088174_Y10HdNxqyBbEFTBctiIDfMBQNO8Ze3p2_jpg.rf.5c53178ad6559ac5581e1ec1592f426d.jpg: 1024x1024 2 Dark Circless, 26.4ms
# image 19/61 /content/datasets/Capstone-9/test/images/245_jpg.rf.8a9e88516a2553f126095bfeb1eb7517.jpg: 1024x1024 5 Acnes, 26.4ms
# image 20/61 /content/datasets/Capstone-9/test/images/254_jpeg_jpg.rf.cc6e3fce5aae4146f87b6dff8a7f577d.jpg: 1024x1024 1 Dark Circles, 2 Wrinkless, 26.1ms
# image 21/61 /content/datasets/Capstone-9/test/images/2569659822_1_jpg.rf.c3e22fc25014e01e786defc39ce980f4.jpg: 1024x1024 2 Dark Circless, 26.0ms
# image 22/61 /content/datasets/Capstone-9/test/images/275_jpg.rf.c407c59816fd64a5b5fa291f38bb05d7.jpg: 1024x1024 19 Acnes, 2 Dark Circless, 26.1ms
# image 23/61 /content/datasets/Capstone-9/test/images/2850227095_1_jpg.rf.4c1861d0f1449dabeb2291f490f81bcb.jpg: 1024x1024 2 Dark Circless, 3 Wrinkless, 26.0ms
# image 24/61 /content/datasets/Capstone-9/test/images/303_jpg.rf.fd1dd3122b16808704612072871c5f84.jpg: 1024x1024 12 Wrinkless, 26.1ms
# image 25/61 /content/datasets/Capstone-9/test/images/309_jpg.rf.865d0b6571617bfce3cecb9438dd93ee.jpg: 1024x1024 1 Acne, 1 Dark Circles, 4 Wrinkless, 26.1ms
# image 26/61 /content/datasets/Capstone-9/test/images/317_jpg.rf.22b217aea867e4171e12addc298069cb.jpg: 1024x1024 4 Wrinkless, 26.1ms
# image 27/61 /content/datasets/Capstone-9/test/images/351_jpg.rf.975e3b72a2836d80501997dcf349b071.jpg: 1024x1024 (no detections), 26.1ms
# image 28/61 /content/datasets/Capstone-9/test/images/366_jpg.rf.96c38784fe925dba10510a741f6f8448.jpg: 1024x1024 8 Wrinkless, 26.1ms
# image 29/61 /content/datasets/Capstone-9/test/images/370_jpg.rf.77c720d4753c2e02bfa96db7f827307e.jpg: 1024x1024 11 Acnes, 26.1ms
# image 30/61 /content/datasets/Capstone-9/test/images/39_jpg.rf.4768e7f35cf75d7122c905b077a8825c.jpg: 1024x1024 2 Acnes, 1 Wrinkles, 26.1ms
# image 31/61 /content/datasets/Capstone-9/test/images/412_jpg.rf.5855e9503bb3fe911e3825cd3b244627.jpg: 1024x1024 7 Acnes, 2 Dark Circless, 26.1ms
# image 32/61 /content/datasets/Capstone-9/test/images/454_jpg.rf.c1d0540f6c2f84866d8abbbabdae92e0.jpg: 1024x1024 6 Acnes, 2 Dark Circless, 26.1ms
# image 33/61 /content/datasets/Capstone-9/test/images/514_jpg.rf.bd67a375773e440223b41e3088f0469b.jpg: 1024x1024 7 Wrinkless, 26.1ms
# image 34/61 /content/datasets/Capstone-9/test/images/52_jpg.rf.93798a8871c28ba6c1c6712d5c08e9d3.jpg: 1024x1024 3 Acnes, 2 Dark Circless, 32.6ms
# image 35/61 /content/datasets/Capstone-9/test/images/52_jpg.rf.ea21d7c0c3a6aae3d5d1472e9c11518c.jpg: 1024x1024 1 Acne, 11 Wrinkless, 32.6ms
# image 36/61 /content/datasets/Capstone-9/test/images/540_jpg.rf.a76fec9acdd644523a64a2bb147a7284.jpg: 1024x1024 4 Acnes, 32.6ms
# image 37/61 /content/datasets/Capstone-9/test/images/550_jpg.rf.fa04d8820f6de51d8b6db211ae5084d6.jpg: 1024x1024 3 Acnes, 1 Dark Circles, 32.6ms
# image 38/61 /content/datasets/Capstone-9/test/images/552_jpg.rf.ca8362ac89009715f5206c70965d1cd2.jpg: 1024x1024 3 Acnes, 32.6ms
# image 39/61 /content/datasets/Capstone-9/test/images/565_jpg.rf.0a23684e00cdec7280c35ee9be7fc2ab.jpg: 1024x1024 2 Dark Circless, 2 Wrinkless, 32.6ms
# image 40/61 /content/datasets/Capstone-9/test/images/589_jpg.rf.5dc69f467a331ab8d745dbb29eec558e.jpg: 1024x1024 1 Acne, 2 Dark Circless, 32.6ms
# image 41/61 /content/datasets/Capstone-9/test/images/594_jpg.rf.705008a50e8b16886d9b26e342d0d082.jpg: 1024x1024 2 Acnes, 1 Dark Circles, 32.6ms
# image 42/61 /content/datasets/Capstone-9/test/images/611_jpg.rf.ba0d978457550f3470f42abc124afe88.jpg: 1024x1024 3 Acnes, 2 Dark Circless, 32.6ms
# image 43/61 /content/datasets/Capstone-9/test/images/612_jpg.rf.91a89baedcfea34cc9c8cc4c9fac8db8.jpg: 1024x1024 1 Acne, 2 Dark Circless, 32.7ms
# image 44/61 /content/datasets/Capstone-9/test/images/613_jpg.rf.259ae3eb3502720190b5415b4c50c83d.jpg: 1024x1024 11 Acnes, 2 Dark Circless, 32.6ms
# image 45/61 /content/datasets/Capstone-9/test/images/617_jpg.rf.3d042b2d6c30e1c9d65bd05e3d868eb7.jpg: 1024x1024 1 Acne, 1 Dark Circles, 32.7ms
# image 46/61 /content/datasets/Capstone-9/test/images/618_jpg.rf.57c8c0b2c27984e7985e286d89723eba.jpg: 1024x1024 1 Dark Circles, 32.5ms
# image 47/61 /content/datasets/Capstone-9/test/images/637_jpg.rf.fa1d41f635979d4b07f94fecaf592156.jpg: 1024x1024 1 Acne, 1 Dark Circles, 32.6ms
# image 48/61 /content/datasets/Capstone-9/test/images/63_jpg.rf.2fa89511b0eb139ad151fd3f7cd89b47.jpg: 1024x1024 9 Acnes, 32.6ms
# image 49/61 /content/datasets/Capstone-9/test/images/63_jpg.rf.3558a39829b1c0a3b58bae7b4b5abaf3.jpg: 1024x1024 1 Acne, 4 Wrinkless, 32.5ms
# image 50/61 /content/datasets/Capstone-9/test/images/655_jpg.rf.e4140cfb2ac481f3eea099ff99303237.jpg: 1024x1024 2 Acnes, 2 Dark Circless, 32.5ms
# image 51/61 /content/datasets/Capstone-9/test/images/658_jpg.rf.1f2b825e35e65c0c5b898608bc38ed41.jpg: 1024x1024 4 Acnes, 2 Dark Circless, 32.5ms
# image 52/61 /content/datasets/Capstone-9/test/images/671_jpg.rf.d66b811bc297d26fc32e1b52b4040603.jpg: 1024x1024 1 Dark Circles, 2 Wrinkless, 32.6ms
# image 53/61 /content/datasets/Capstone-9/test/images/680_jpg.rf.ed68f5858f7d57c71f82d76d93d2eb6b.jpg: 1024x1024 5 Acnes, 32.5ms
# image 54/61 /content/datasets/Capstone-9/test/images/684_jpg.rf.ba2372683c79137550803a7d57ee645d.jpg: 1024x1024 2 Acnes, 1 Wrinkles, 32.5ms
# image 55/61 /content/datasets/Capstone-9/test/images/76_jpg.rf.51313e5ad3c97f3cdb5990be7772f04c.jpg: 1024x1024 1 Acne, 3 Wrinkless, 32.5ms
# image 56/61 /content/datasets/Capstone-9/test/images/86_jpg.rf.c507d23282f84666a4e38532cee51166.jpg: 1024x1024 3 Acnes, 1 Wrinkles, 32.5ms
# image 57/61 /content/datasets/Capstone-9/test/images/97_jpg.rf.ed2835ab9db419f8cdfd81d357eed992.jpg: 1024x1024 7 Acnes, 32.5ms
# image 58/61 /content/datasets/Capstone-9/test/images/_1569766202356_jpg.rf.76506cfcb70b71b9fcf87106e6bf62b9.jpg: 1024x1024 2 Dark Circless, 32.5ms
# image 59/61 /content/datasets/Capstone-9/test/images/_1578665882987_jpg.rf.1c895368e6f1224d79d114a3c5d96860.jpg: 1024x1024 2 Dark Circless, 32.4ms
# image 60/61 /content/datasets/Capstone-9/test/images/_1581747201206_jpg.rf.b00cc96a0a2c02024b5242714c372f21.jpg: 1024x1024 2 Dark Circless, 1 Wrinkles, 32.5ms
# image 61/61 /content/datasets/Capstone-9/test/images/_1582980360065_jpg.rf.172402f654994772f976ba5b5d68b628.jpg: 1024x1024 2 Dark Circless, 32.5ms
# Speed: 8.8ms preprocess, 30.5ms inference, 10.7ms postprocess per image at shape (1, 3, 1024, 1024)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/val_batch0_pred.jpg', width=600)
# Out:
# /content

# %% [markdown]
# ## Export

# %%
folder_path = '/content/runs/detect/train/'
zip_path = '/content/v9M4_50_1024.zip'
shutil.make_archive(zip_path.replace('.zip', ''), 'zip', folder_path)
files.download(zip_path)

# %%
best_model_path = 'runs/detect/train/weights/best.pt'
shutil.copy(best_model_path, 'v9M4_50_1024.pt')
files.download('v9M4_50_1024.pt')
